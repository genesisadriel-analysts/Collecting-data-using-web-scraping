# %% [markdown]
# # **Web Scraping**
#
# ##
# Objectives
#
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables
#
# ## Scrape www.ibm.com
#
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/events/think?lnk=hpprus&utm_id=PBushp
# https://www.ibm.com/thought-leadership/institute-business-value/report/agentic-ai-cybersecurity?lnk=hpls1us
# https://www.ibm.com/solutions/ai-cybersecurity?lnk=hpls2us
# https://research.ibm.com/blog/signal-threema-quantum-safe?lnk=hprc1us
# https://ibm.webcasts.com/starthere.jsp?ei=1755597&tp_key=10f0b8919a&sti=hp&lnk=hprc2us
# https://www.ibm.com/think/insights/more-2026-cyberthreat-trends?lnk=hprc3us
# https://skillsbuild.org/adult-learners/explore-learning/cybersecurity-analyst?lnk=hprc4us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs4us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/case-studies/ufc?lnk=hpcs1us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs2us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/software/ai-productivity?lnk=hpfp2us
# https://www.ibm.com/software/data-management?lnk=hpfp3us
# https://www.ibm.com/software/security-governance?lnk=hpfp4us
# https://www.ibm.com/software/integration-resilience?lnk=hpfp5us
# https://www.ibm.com/software/hybrid-infrastructure-management?lnk=hpfp6us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp7us
# https://www.ibm.com/solutions/analytics?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# None
# https://www.ibm.com/training?utm_source=hp&utm_campaign=ushp&utm_medium=organic&lnk=hptr3us
# https://skillsbuild.org/adult-learners?lnk=hptr2us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://skillsbuild.org/college-students?lnk=hptr1us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://newsroom.ibm.com/2026-03-26-ibm-quantum-computer-accurately-simulates-real-magnetic-materials,-reproducing-national-laboratory-data
# https://newsroom.ibm.com/2026-03-25-enterprise-ai-finds-its-voice-elevenlabs-and-ibm-bring-premium-voice-capabilities-to-agentic-ai
# https://newsroom.ibm.com/2026-03-23-ibm-debuts-new-ai-enabled-digital-experiences-for-the-90th-masters-tournament
# https://newsroom.ibm.com/2026-03-18-ibm-fellow-and-quantum-pioneer-charles-h-bennett-receives-a-m-turing-award-computings-highest-honor
# https://newsroom.ibm.com/2026-03-17-ibm-completes-acquisition-of-confluent,-making-real-time-data-the-engine-of-enterprise-ai-and-agents
# https://newsroom.ibm.com/2026-03-16-ibm-and-nvidia-announce-expanded-collaboration-at-gtc-2026-to-advance-ai-for-the-enterprise
# https://newsroom.ibm.com/2026-03-12-ibm-releases-a-new-blueprint-for-quantum-centric-supercomputing
# https://newsroom.ibm.com/2026-03-10-ibm-and-lam-research-announce-collaboration-to-advance-sub-1nm-logic-scaling

# %% [markdown]
# Scrape all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/r4u-quantum-a_1?ts=1774451492434&dpr=off
# https://assets.ibm.com/is/image/ibm/r4u-identity-a_2?ts=1774451493335&dpr=off
# https://assets.ibm.com/is/image/ibm/r4u-cyber-risk-a_1?ts=1774451507339&dpr=off
# https://assets.ibm.com/is/image/ibm/r4u-security-skills-a_2?ts=1774451513906&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1774451517672&dpr=off
# https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1774451520503&dpr=off
# https://assets.ibm.com/is/image/ibm/16-9-logo-ufc?ts=1774451523452&dpr=off
# https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1774451526313&dpr=off
# https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1774451517325&dpr=off
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1774451520145&dpr=off
# https://assets.ibm.com/is/image/ibm/ufc-octagon-9?ts=1774451523062&dpr=off
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1774451525945&dpr=off
# https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1774451527228&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1774285682025&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1774451533585&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1774451531905&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1774451538098&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## **Collecting Data Using Web Scraping**
#
# ## Objectives
#
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.
#
# Import the required libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
response = requests.get(url)
response.raise_for_status()

# %% [markdown]
# Create a soup object

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
table = soup.find("table")

data = []

for row in table.find_all("tr")[1:]:
    cols = row.find_all("td")
    if len(cols) >= 4:
        language = cols[1].get_text(strip=True)
        salary = cols[3].get_text(strip=True)
        data.append([language, salary])
df = pd.DataFrame(data, columns=["Programming Language", "Average Annual Salary"])

print(df)
# Out:
#   Programming Language Average Annual Salary
# 0               Python              $114,383
# 1                 Java              $101,013
# 2                    R               $92,037
# 3           Javascript              $110,981
# 4                Swift              $130,801
# 5                  C++              $113,865
# 6                   C#               $88,726
# 7                  PHP               $84,727
# 8                  SQL               $84,793
# 9                   Go               $94,082

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
df.to_csv("popular-languages.csv", index=False)
print('File saved sucessfully..')
# Out:
# File saved sucessfully..
